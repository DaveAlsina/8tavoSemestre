# %%
include("jacobi.jl")
# Out:
# jacobi (generic function with 1 method)

# %%
A = [10 -1  2  0;
     -1 11 -1  3;
      2 -1 10 -1;
      0  3 -1  8]
b = [6, 25, -11, 15]

jacobi(A, b)
# Out:
# 4-element Vector{Float64}:
#   0.6000000000000001
#   2.272727272727273
#  -1.1
#   1.875
