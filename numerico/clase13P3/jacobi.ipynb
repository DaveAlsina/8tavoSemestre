# %%
include("iterative_methods.jl")
# Out:
# iterative_refinement (generic function with 1 method)

# %%
A = [10 -1  2  0;
     -1 11 -1  3;
      2 -1 10 -1;
      0  3 -1  8]
b = [6, 25, -11, 15]
x = [0, 0, 0, 0]
tol = 1e-6

jacobi(A, b, x, tol)
# Out:
# 4-element Vector{Float64}:
#   0.9999999398374981
#   2.0000000983782202
#  -1.0000000767014612
#   1.0000001117564756

# %%
A = [10 -1  2  0;
     -1 11 -1  3;
      2 -1 10 -1;
      0  3 -1  8]
b = [6, 25, -11, 15]
x = [0, 0, 0, 0]
tol = 1e-6

gauss_siedel(A, b, x, tol)
# Out:
# 4-element Vector{Float64}:
#   1.0000000442852197
#   1.9999999946606366
#  -1.0000000129277868
#   1.0000000003862881

# %%
A = [10 -1  2  0;
     -1 11 -1  3;
      2 -1 10 -1;
      0  3 -1  8]
b = [6, 25, -11, 15]
x = [0, 0, 0, 0]
tol = 1e-6

iterative_refinement(A, b, x, tol)
# Out:
# 4-element Vector{Float64}:
#   1.0
#   1.9999999999999998
#  -1.0
#   1.0000000000000002
